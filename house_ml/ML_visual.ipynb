# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("preprocessed_price.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  int64
#  1   location    13320 non-null  int64
#  2   size        13320 non-null  int64
#  3   total_sqft  13320 non-null  float64
#  4   bath        13320 non-null  float64
#  5   balcony     13320 non-null  float64
#  6   price       13320 non-null  float64
# dtypes: float64(4), int64(3)
# memory usage: 728.6 KB

# %%
dataset.describe()
# Out:
#           area_type      location          size    total_sqft          bath  \
# count  13320.000000  13320.000000  13320.000000  13320.000000  13320.000000
# mean       0.977027    672.659009     14.791291   1559.626694      2.692610
# std        0.582742    365.024806      4.455820   1236.264860      1.337777
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000    397.000000     13.000000   1100.000000      2.000000
# 50%        1.000000    654.000000     16.000000   1279.500000      2.000000
# 75%        1.000000    999.000000     16.000000   1678.000000      3.000000
# max        2.000000   1305.000000     30.000000  52272.000000     40.000000
#
#             balcony         price
# count  13320.000000  13320.000000
# mean       1.584376    112.565627
# std        0.798360    148.971674
# min        0.000000      8.000000
# 25%        1.000000     50.000000
# 50%        2.000000     72.000000
# 75%        2.000000    120.000000
# ...

# %%
correlation=dataset.corr()

# %%
correlation
# Out:
#             area_type  location      size  total_sqft      bath   balcony  \
# area_type    1.000000  0.016141  0.224819    0.041820  0.240820 -0.017673
# location     0.016141  1.000000  0.006733    0.040147  0.003764  0.003024
# size         0.224819  0.006733  1.000000    0.316840  0.675410  0.242893
# total_sqft   0.041820  0.040147  0.316840    1.000000  0.389874  0.135905
# bath         0.240820  0.003764  0.675410    0.389874  1.000000  0.182804
# balcony     -0.017673  0.003024  0.242893    0.135905  0.182804  1.000000
# price        0.183587  0.011425  0.334794    0.574945  0.455397  0.103989
#
#                price
# area_type   0.183587
# location    0.011425
# size        0.334794
# total_sqft  0.574945
# bath        0.455397
# balcony     0.103989
# price       1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'correlation' is your correlation matrix
plt.figure(figsize=(8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='0.1f', annot=True, annot_kws={'size': 8}, cmap='Reds')
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
dataset
# Out:
#        area_type  location  size  total_sqft  bath   balcony   price
# 0              1       419    13      1056.0   2.0  1.000000   39.07
# 1              2       317    19      2600.0   5.0  3.000000  120.00
# 2              0      1179    16      1440.0   2.0  3.000000   62.00
# 3              1       757    16      1521.0   3.0  1.000000   95.00
# 4              1       716    13      1200.0   2.0  1.000000   51.00
# ...          ...       ...   ...         ...   ...       ...     ...
# 13315          0      1252    22      3453.0   4.0  0.000000  231.00
# 13316          1      1004    18      3600.0   5.0  1.584376  400.00
# 13317          0       972    13      1141.0   2.0  1.000000   60.00
# 13318          1       907    18      4689.0   4.0  1.000000  488.00
# 13319          1       396     0       550.0   1.0  1.000000   17.00
#
# [13320 rows x 7 columns]

# %%
sns.pairplot(dataset[['total_sqft','bath']])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#univariate
# For numerical features (e.g., 'price')
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=True, bins=30, color='blue')
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['price'], color='orange')
plt.title('Price Distribution - Box Plot')
plt.xlabel('Price')
plt.show()

# Summary statistics for numerical features
print(df['price'].describe())

# For categorical features (e.g., 'area_type')
plt.figure(figsize=(8, 6))
sns.countplot(x='area_type', data=df, palette='Set2')
plt.title('Distribution of Area Types')
plt.xlabel('Area Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       4 #univariate
#       5 # For numerical features (e.g., 'price')
#       6 # Histogram
#       7 plt.figure(figsize=(8, 6))
# ----> 8 sns.histplot(df['price'], kde=True, bins=30, color='blue')
#       9 plt.title('Distribution of House Prices')
#      10 plt.xlabel('Price')
#
# NameError: name 'df' is not defined

# %%
#bivariate
# 1. Numerical vs Numerical - Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total_sqft', y='price', data=df, color='green')
plt.title('Scatter plot of Total Square Feet vs Price')
plt.xlabel('Total Square Feet')
plt.ylabel('Price')
plt.show()

# 2. Numerical vs Categorical - Box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='area_type', y='price', data=df, palette='Set1')
plt.title('Price Distribution by Area Type')
plt.xlabel('Area Type')
plt.ylabel('Price')
plt.show()

# 3. Categorical vs Categorical - Heatmap of Correlation (e.g., area_type vs location)
# If both variables are encoded as numerical values (e.g., using LabelEncoder)
plt.figure(figsize=(8, 6))
sns.heatmap(df[['area_type', 'location']].corr(), annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation between Area Type and Location')
plt.show()
